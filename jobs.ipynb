# %%
from sklearn.utils import shuffle

df = pd.read_csv("postings.csv")
df = shuffle(df)
data = df[:600]
data
# Out:
#             job_id                      company_name  \
# 56821   3901941311                        VinFast US
# 120236  3906228709                      Sunglass Hut
# 116415  3905868666       Millennium Recruiting, Inc.
# 69299   3902806222                         Capgemini
# 46742   3900978159                 Ultimate Staffing
# ...            ...                               ...
# 104453  3905298847                  Bose Corporation
# 123818  3906264345  TalentBurst, an Inc 5000 company
# 14307   3887867856              Southland Industries
# 245     3706460061             Sharper Office Admin
# 42480   3899535580                 Molina Healthcare
#
#                                                     title  \
# 56821                         Internal Control Specialist
# 120236                       Sales Associate Sunglass Hut
# 116415                              Fundraising Associate
# 69299                        Javascript Developer- React
# ...

# %%
del data['job_id']
del data['company_name']
del data['company_id']
del data['views']
del data['posting_domain']
del data['sponsored']
del data['zip_code']
del data['fips']
del data['listed_time']
del data['original_listed_time']

data
# Out:
#                                                     title  \
# 56821                         Internal Control Specialist
# 120236                       Sales Associate Sunglass Hut
# 116415                              Fundraising Associate
# 69299                        Javascript Developer- React
# 46742                            Front Office Coordinator
# ...                                                   ...
# 104453                             Ecommerce Merchandiser
# 123818                                   Quality Engineer
# 14307                    Human Resources Business Partner
# 245                     Admininistrative Assistant Intern
# 42480   Case Manager, LTSS (RN) - Field Travel in Rock...
#
#                                               description  max_salary  \
# 56821   JOB SUMMARY:Reporting to the Director, Interna...   120000.00
# 120236  Requisition ID: 843252\n\nStore #: 003543 Sung...         NaN
# ...

# %%
data.to_csv('600_jobs.csv')
